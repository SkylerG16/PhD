# %%
# NOTEBOOK NAME
# BARRADataSandbox1.ipynb
# NOTEBOOK NAME

# OPENING IMPORTS
import numpy as np
from matplotlib import pyplot as plt
import xarray as xr
from datetime import datetime

# for interpolation
from scipy.interpolate import interp1d

# used to play with pathnames to save 
from pathlib import Path      

# # SPECIAL METHOD TO IMPORT LEROI RADAR GRIDDING PACKAGE AND CUSTOM FUNCTIONS FROM LOCAL DIRECTORY
import sys
sys.path.append('/home/563/sg3241/Notebooks/CustomFunctions')
from CustomFunctions1 import *
from custom_elevation import fetch_srtm, fetch_gebco_local

# for projecting radar coordinates to lat and lon
from pyproj import Geod

# for making cool topo maps
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.colors import ListedColormap, BoundaryNorm

# for adding lat/lon gridlines on plots
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LATITUDE_FORMATTER, LONGITUDE_FORMATTER

# %%
# THIS BLOCK LOADS IN A MONTH-LONG HOURLY BARRA DATA BLOCK FOR TEMPERATURE AT ALL* (MOST) PRESSURE LEVELS

# choose the year and the month you want to look at data for
year  = 2024
month = 2

# add leading zeros if neccessary to the year and month strings
YYYY = str(year).zfill(4)
MM   = str(month).zfill(2)

# pressure levels with temperature variables associated with them
PLevels = [1000, 925, 850, 700, 600, 500, 400, 300, 200] #, #950] # the kernel sometimes crashes when I include 200 hPa
# there is no geopotential height data for 950 hPa, but there is temperature data

# create an empty data structure carrying-bag
TBarraDataStructs = {}

# loop through each pressure level and grab a lat-lon slice over Queensland 
for PLevel in PLevels:
    
    Tvariable = 'ta' + str(PLevel)

    # where the BARRA data live
    TBARRAfolder = f'/g/data/ob53/BARRA2/output/reanalysis/AUS-11/BOM/ERA5/historical/hres/BARRA-R2/v1/1hr/{Tvariable}/latest/'
    TBARRAfile = Tvariable + f'_AUS-11_ERA5_historical_hres_BOM_BARRA-R2_v1_1hr_{YYYY}{MM}-{YYYY}{MM}.nc'
    TBARRApath = TBARRAfolder + TBARRAfile

    Tdata = xr.open_dataset(TBARRApath)

    # take that Queensland slice
    Tdata = Tdata.sel(
        lat=slice(-30, -10),
        lon=slice(140, 160)
    )

    # make sure the temperature variable is named the same in each data array
    Tdata = Tdata.rename({Tvariable: "ta"})

    # store that slice away
    TBarraDataStructs[PLevel] = Tdata

    
# combine all of the loaded temperature data arrays for each pressure level into one data array
Tdatasets = [TBarraDataStructs[Plevel] for Plevel in PLevels]

TGrandData = xr.concat(
    Tdatasets,
    dim=xr.DataArray(PLevels, dims="pressure", name="pressure")
)

# add attributes to the new pressure coordinate
TGrandData['pressure'].attrs = {
    'long_name': 'pressure',
    'standard_name': 'pressure',
    'units': 'hPa',
    'axis': 'P'
}






# REPEAT THE EXACT SAME THING BUT FOR PRESSURE GEOPOTENTIAL HEIGHTS INSTEAD OF TEMPERATURE
# create an empty data structure carrying-bag
ZBarraDataStructs = {}
# loop through each pressure level and grab a lat-lon slice over Queensland 
for PLevel in PLevels:
    
    Zvariable = 'zg' + str(PLevel)

    # where the BARRA data live
    ZBARRAfolder = f'/g/data/ob53/BARRA2/output/reanalysis/AUS-11/BOM/ERA5/historical/hres/BARRA-R2/v1/1hr/{Zvariable}/latest/'
    ZBARRAfile = Zvariable + f'_AUS-11_ERA5_historical_hres_BOM_BARRA-R2_v1_1hr_{YYYY}{MM}-{YYYY}{MM}.nc'
    ZBARRApath = ZBARRAfolder + ZBARRAfile

    Zdata = xr.open_dataset(ZBARRApath)

    # take that Queensland slice
    Zdata = Zdata.sel(
        lat=slice(-30, -10),
        lon=slice(140, 160)
    )

    # make sure the temperature variable is named the same in each data array
    Zdata = Zdata.rename({Zvariable: "zg"})

    # store that slice away
    ZBarraDataStructs[PLevel] = Zdata

    
# combine all of the loaded temperature data arrays for each pressure level into one data array
Zdatasets = [ZBarraDataStructs[Plevel] for Plevel in PLevels]

ZGrandData = xr.concat(
    Zdatasets,
    dim=xr.DataArray(PLevels, dims="pressure", name="pressure")
)

# add attributes to the new pressure coordinate
ZGrandData['pressure'].attrs = {
    'long_name': 'pressure',
    'standard_name': 'pressure',
    'units': 'hPa',
    'axis': 'P'
}

# %%
# make a plot for temperature

fig, ax = plt.subplots(figsize=(8,6))
RangeViewer = pcolormeshC(TGrandData.lon, TGrandData.pressure, TGrandData.ta[:,324,80,:]-273.15, ax=ax, cmap='nipy_spectral', vmin=-40, vmax=40)

ax.set_xlabel('Longitude [Degrees East]')
ax.set_ylabel('Pressure Level [hPa]')
plt.gca().invert_yaxis()

plt.colorbar(RangeViewer, ax=ax, label = 'Temperature [Celsius]')
plt.grid()

plt.show()

# %%
# make a plot for geopotential height

fig, ax = plt.subplots(figsize=(8,6))
RangeViewer = pcolormeshC(ZGrandData.lon, ZGrandData.pressure, ZGrandData.zg[:,324,80,:]*0.001, ax=ax, cmap='nipy_spectral', vmin=0, vmax=14)
                                                                                        # convert to km
ax.set_xlabel('Longitude [Degrees East]')
ax.set_ylabel('Pressure Level [hPa]')
plt.gca().invert_yaxis()

plt.colorbar(RangeViewer, ax=ax, label = 'Geopotenital Height [km]')
plt.grid()

plt.show()

# %%
# CHAD ATTEMPT
# interpolates with height

from scipy.interpolate import interp1d

# --- Select your slice (same indices as before) ---
# Shape after selection: (pressure: 8, lon: 182)
T_slice = TGrandData.ta[:, 324, 80, :] - 273.15   # (pressure, lon)
Z_slice = ZGrandData.zg[:, 324, 80, :]             # (pressure, lon)

# --- Define a common height grid to interpolate onto ---
z_min = float(Z_slice.min())
z_max = float(Z_slice.max())
n_levels = 100  # adjust for resolution
z_common = np.linspace(z_min, z_max, n_levels)     # (n_levels,)

# --- Interpolate T onto common height grid for each longitude column ---
n_lon = T_slice.shape[1]
T_interp = np.full((n_levels, n_lon), np.nan)

for i in range(n_lon):
    z_col = Z_slice[:, i].values   # height at each pressure level for this lon
    t_col = T_slice[:, i].values   # temperature at each pressure level

    # Ensure heights are monotonically increasing for interp1d
    sort_idx = np.argsort(z_col)
    z_sorted = z_col[sort_idx]
    t_sorted = t_col[sort_idx]

    f = interp1d(z_sorted, t_sorted, bounds_error=False, fill_value=np.nan)
    T_interp[:, i] = f(z_common)

# --- Plot ---
fig, ax = plt.subplots(figsize=(8, 6))

RangeViewer = ax.pcolormesh(
    TGrandData.lon.values,
    z_common*0.001, # convert to km
    T_interp,
    cmap='nipy_spectral',
    vmin=-40,
    vmax=40
)

ax.set_xlabel('Longitude [Degrees East]')
ax.set_ylabel('Geopotential Height [km]')

plt.colorbar(RangeViewer, ax=ax, label='Temperature [Celsius]')
plt.grid()
plt.show()

# %%
# CHAD ATTEMPT
# does not interpolate with height

# --- Select your slice ---
T_slice = TGrandData.ta[:, 324, 80, :] - 273.15   # (pressure, lon)
Z_slice = ZGrandData.zg[:, 324, 80, :]             # (pressure, lon)

# --- Convert to numpy ---
Z_vals = Z_slice.values.copy()
T_vals = T_slice.values.copy()

# --- Combined NaN mask: True wherever EITHER variable is NaN ---
nan_mask = np.isnan(Z_vals) | np.isnan(T_vals)

# --- Apply fill value to both ---
fill_value = -9
Z_vals[nan_mask] = fill_value
T_vals[nan_mask] = np.nan  # pcolormesh won't render these but keeps arrays clean

# --- Build 2D longitude array ---
lon_2d = np.broadcast_to(TGrandData.lon.values, Z_slice.shape).copy()

# --- Plot ---
fig, ax = plt.subplots(figsize=(8, 6))

RangeViewer = ax.pcolormesh(
    lon_2d,
    Z_vals*0.001, # convert to km
    T_vals,
    cmap='nipy_spectral',
    vmin=-40,
    vmax=40
)

ax.set_xlabel('Longitude [Degrees East]')
ax.set_ylabel('Geopotential Height [km]')

plt.colorbar(RangeViewer, ax=ax, label='Temperature [Celsius]')
plt.grid()
plt.show()

# %%
# TRY TO PLOT BARRA 2 POINTS ON A  RADAR MAP

# CHOOSE THE RADAR
RadarIDno = '22'  # 22 is Mackay, 106 is Townsville, 66 is Mt Staplyton (Brisbane) , 50 is Marabong (near Brisbane)
RadarSiteName = 'Mackay' 
RadarFileDate = '20240309'
RadarFileDatePrint = '2024-03-09'
RadarFileTime = '120000'

BoxRange = 150

NetCDFstorageFolder = '/scratch/v46/sg3241/tmp/UnzippedRadarFiles/' + RadarIDno + '/' + RadarIDno + '_' + RadarFileDate + '_ppi' + '/'
NetCDFstorageFile = RadarIDno + '_' + RadarFileDate + '_' + RadarFileTime + '_ppi.nc'
NetCDFstoragePath = NetCDFstorageFolder + NetCDFstorageFile

# try to load in the netcdf file and if it doesn't work, just keep going
try:
    RadarXR = xr.open_dataset(NetCDFstoragePath, decode_timedelta = False) # add the decode_timedelta to shut up a warning
except FileNotFoundError:
    print(f'File missing for {RadarFileTimePrint}, skipping: {NetCDFstoragePath}')

RadarDate = datetime.strptime(RadarFileDate, '%Y%m%d')
# --- Select only the 24 hours of that day from the BARRA data ---
TDayData = TGrandData.sel(time=(TGrandData.time.dt.date == RadarDate.date()))
ZDayData = ZGrandData.sel(time=(ZGrandData.time.dt.date == RadarDate.date()))


# calculate the effective radius of the earth given standard refraction
RadiusEarth = 6371000 # [m]
RadiusEarthEff = RadiusEarth * (4/3)

# load in a "geodesic calculator"
geod = Geod(ellps='WGS84')

# read in the PPI coordinates from the xarray dataframe
Ranges  = RadarXR['range'].values
AziDegs = RadarXR['azimuth'].values
EleDegs = RadarXR['elevation'].values

# read in the radar site location from the xarray dataframe
SiteLat = float(RadarXR.latitude)
SiteLon = float(RadarXR.longitude)
SiteAlt = float(RadarXR.altitude)

# convert angles to radians
AziRads = np.deg2rad(AziDegs)[:,None]
EleRads = np.deg2rad(EleDegs)[:,None]

# I AM UNCERTAIN OF THIS TRIGONOMETRIC FORMULA

# Distance from Centre of the Earth using 4/3 Earth-radius model
DistsFromCOE = np.sqrt(    (Ranges**2)  +  (RadiusEarthEff**2)  +  (2.0 * Ranges * RadiusEarthEff * np.sin(EleRads))     )
# Convert to altitude by subtracting out the earth and adding in the site elevation
Alts = (DistsFromCOE - RadiusEarthEff) + SiteAlt

# MAYBE THIS FORMULA SHOULD ALSO TAKE INTO ACCOUNT EARTH CURVATURE?

# calculate range in distance along the surface of Earth
GroundRanges = Ranges * np.cos(EleRads)  # distance along surface [m]
# the last line adds a dimension of 1 at the end for some reason that I remove here:
GroundRanges = np.squeeze(GroundRanges)

# retrieve number of ranges and gates in the ppi file
NumRays, NumGates = GroundRanges.shape

# for i in range(NumRays):
    
# Broadcast (repeat) radar site lon/lat and azimuth to match GroundRanges shape
SiteLonRep = np.full_like(GroundRanges, SiteLon, dtype=float)
SiteLatRep = np.full_like(GroundRanges, SiteLat, dtype=float)

AziDegsRep= np.repeat(AziDegs[:, None], NumGates, axis=1)
# AziDegsRep = np.full_like(GroundRanges, AziDegs, dtype=float)

Lons, Lats, _ = geod.fwd(SiteLonRep, SiteLatRep, AziDegsRep, GroundRanges)


# turn the calculated latitudes and longitudes and altitudes for each range gate into xarray elements 

LatsData = xr.DataArray(Lats, dims=('time', 'range'), name='gate_latitude',
    attrs={
        'long_name': 'latitude of radar gates',
        'units': 'degrees_north'})

LonsData = xr.DataArray(Lons, dims=('time', 'range'), name='gate_longitude',
    attrs={
        'long_name': 'longitude of radar gates',
        'units': 'degrees_east'})

AltsData = xr.DataArray(Alts, dims=('time', 'range'), name='gate_altitude',
    attrs={
        'long_name': 'altitude of radar gates',
        'units': 'm',
        'standard_name': 'altitude'})


# and add them as variables to your radar data
RadarXR['gate_latitude']  = LatsData
RadarXR['gate_longitude'] = LonsData
RadarXR['gate_altitude']  = AltsData

fig, ax = plt.subplots(figsize=(10, 8), 
                       subplot_kw={'projection': ccrs.PlateCarree()})

# gebco_path = '/home/563/sg3241/QueenslandElevationGEBCO.nc'
# EXPERIMENTAL TOPO SHADING SECTION
# EXPERIMENTAL TOPO SHADING SECTION
# EXPERIMENTAL TOPO SHADING SECTION

# TERRAIN SHADING USING LOCAL GEBCO DEM
lon_min, lon_max = float(RadarXR.gate_longitude.min()), float(RadarXR.gate_longitude.max())
lat_min, lat_max = float(RadarXR.gate_latitude.min()), float(RadarXR.gate_latitude.max())

try:
    # Path to your GEBCO NetCDF
    gebco_path = '/home/563/sg3241/QueenslandElevationGEBCO.nc'

    # Use the helper to get a subset over the radar domain
    dem_da = fetch_gebco_local(gebco_path, lon_min, lon_max, lat_min, lat_max)

    if dem_da is not None:
        # dem_da is an xarray.DataArray with coords lon, lat
        dem_lon = dem_da.lon.values
        dem_lat = dem_da.lat.values
        dem_data = dem_da.values

        # Make 2D lon/lat grids if necessary
        if dem_lon.ndim == 1 and dem_lat.ndim == 1:
            dem_lon_2d, dem_lat_2d = np.meshgrid(dem_lon, dem_lat)
        else:
            dem_lon_2d, dem_lat_2d = dem_lon, dem_lat

        # Ensure we have some valid data
        valid = np.isfinite(dem_data)
        if not np.any(valid):
            raise ValueError('DEM has no finite values in this domain')

        colours = [
            '#dde4e8',  # 0: pale blue-grey (ocean, < 0 m)
        
            '#c4dec2',  # 1: 0–200 m, pale green
            '#e4edc9',  # 2: 200–400 m, greenish-yellow
            '#f3f0cf',  # 3: 400–600 m, pale yellow-beige
            '#e9d7bd',  # 4: 600–800 m, light tan
            '#ddc4aa',  # 5: 800–1000 m, tan
            '#cfb194',  # 6: 1000–1200 m, light brown
            '#b58f6e',  # 7: > 1200 m, darker brown
        ]
        
        bounds = [
            -1000.0,  # ocean below 0
            0.0,      # 0–200
            200.0,    # 200–400
            400.0,    # 400–600
            600.0,    # 600–800
            800.0,    # 800–1000
            1000.0,   # 1000–1200
            1200.0,   # > 1200
            5000.0,
        ]
        
        cmap_elev = ListedColormap(colours)
        norm = BoundaryNorm(bounds, len(colours), clip=True)
        
        # Plot as semi‑transparent background
        elev_plot = ax.pcolormesh(
            dem_lon_2d,
            dem_lat_2d,
            dem_data,
            cmap=cmap_elev,
            norm=norm,
            alpha=1.0,
            transform=ccrs.PlateCarree(),
            # zorder=2,
        )

        # Draw 0 m contour as an accurate coastline
        coast_contour = ax.contour(
            dem_lon_2d,
            dem_lat_2d,
            dem_data,
            levels=[0.0],
            colors='black',
            linewidths=0.5,
            transform=ccrs.PlateCarree(),
            zorder=15,  # above radar and topo
        )

        # Draw 400 m contour
        coast_contour = ax.contour(
            dem_lon_2d,
            dem_lat_2d,
            dem_data,
            levels=[400.0],
            colors='black',
            linewidths=0.3,
            transform=ccrs.PlateCarree(),
            zorder=15,  # above radar and topo
        )

        print('Terrain shading (GEBCO, discrete bands) + coastline loaded successfully')

    else:
        raise ValueError('GEBCO DEM returned None')

except Exception as e:
    print(f'Terrain shading failed: {e}')
    print('Falling back to simple land/ocean shading')
    ax.add_feature(cfeature.OCEAN, facecolor='lightblue', alpha=0.3, zorder=1)
    ax.add_feature(cfeature.LAND, facecolor='#E8E8E8', alpha=0.3, zorder=2)

ax.add_feature(cfeature.BORDERS, linewidth=0.5, alpha=0.5, zorder=3)
# END EXPERIMENTAL TOPO SHADING SECTION
# END EXPERIMENTAL TOPO SHADING SECTION
# END EXPERIMENTAL TOPO SHADING SECTION

# --- Radar location ---
ax.plot(float(RadarXR.longitude), float(RadarXR.latitude),
        marker='*', markersize=15, color='red',
        transform=ccrs.PlateCarree(), zorder=20,
        label=f'{RadarSiteName} Radar Site')

# ADD a circle of radius BoxRange km around the radar site ---
# Generate angles around the circle
angles = np.linspace(0, 360, 360)

# Use pyproj geod to calculate points at BoxRange km distance in each direction
circle_lons, circle_lats, _ = geod.fwd(
    np.full_like(angles, float(RadarXR.longitude)),  # repeat site lon for each angle
    np.full_like(angles, float(RadarXR.latitude)),   # repeat site lat for each angle
    angles,                                           # azimuth angles 0–360
    np.full_like(angles, BoxRange * 1000)             # radius in metres
)

# --- Range circle ---
ax.plot(circle_lons, circle_lats,
        color='red', linewidth=1.5, linestyle='--',
        transform=ccrs.PlateCarree(), zorder=20,
        label=f'{BoxRange} km Range Ring')



# --- BARRA grid points ---
barra_lon_2d, barra_lat_2d = np.meshgrid(TGrandData.lon.values, TGrandData.lat.values)
ax.plot(barra_lon_2d.ravel(), barra_lat_2d.ravel(),
        marker='.', markersize=3, color='blue', linestyle='none',
        transform=ccrs.PlateCarree(), zorder=19,
        label='BARRA-C2 Grid Points')

# ADD A LEGEND
ax.legend(loc='upper left',
          bbox_to_anchor=(1.01, 0.9),   # (x, y) in axes coordinates — just right of axes, bottom
          borderaxespad=0,
          framealpha=0.8,
          markerscale=1.5)

# Add MINOR gridlines (half degrees) - thin
gl_minor = ax.gridlines(draw_labels=False, alpha=0.8, zorder=11, linewidth=0.3)
gl_minor.xlocator = mticker.MultipleLocator(0.1)  # Every 0.5 degrees
gl_minor.ylocator = mticker.MultipleLocator(0.1)  # Every 0.5 degrees

# Add MAJOR gridlines (full degrees) - thick with labels
gl_major = ax.gridlines(draw_labels=True, alpha=0.8, zorder=12, linewidth=0.5)
gl_major.xlocator = mticker.MultipleLocator(0.5)  # Every 1 degree
gl_major.ylocator = mticker.MultipleLocator(0.5)  # Every 1 degree

# Format labels
gl_major.xformatter = LONGITUDE_FORMATTER
gl_major.yformatter = LATITUDE_FORMATTER

# Remove labels from top and right
gl_major.top_labels = False
gl_major.right_labels = False
gl_major.bottom_labels = True
gl_major.left_labels = True

# calculate how many degrees this range is (different for latitude vs longitude)
RadiusEarth = 6371 # [km]
kmPerDegLat = (RadiusEarth * 2 * np.pi) /360
kmPerDegLon = kmPerDegLat * np.cos( np.deg2rad(RadarXR.latitude))

BoxRangeDegLat = BoxRange / kmPerDegLat
BoxRangeDegLon = BoxRange / kmPerDegLon

plt.xlim([float(RadarXR.longitude)  - BoxRangeDegLon, float(RadarXR.longitude)  + BoxRangeDegLon])
plt.ylim([float(RadarXR.latitude)   - BoxRangeDegLat,  float(RadarXR.latitude)  + BoxRangeDegLat])

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

plt.title(RadarSiteName + ' BARRA Grid Points')

plt.tight_layout()

SaveFolder = '/scratch/v46/sg3241/tmp/pngImages/'
SaveFile   = RadarIDno + '_BARRApoints.png'

SavePath = SaveFolder + SaveFile

if not Path(SaveFolder).exists():
    print('Creating Folder: ' + SaveFolder)
    Path(SaveFolder).mkdir(parents=True, exist_ok=True)

plt.savefig(SavePath, bbox_inches='tight', facecolor='w', dpi = 300)
plt.close()

# %%
# --- Create a mask of BARRA grid points within BoxRange km of the radar ---

# Build 2D meshgrid of all BARRA lat/lon combinations
barra_lon_2d, barra_lat_2d = np.meshgrid(TGrandData.lon.values, TGrandData.lat.values)

# Calculate the geodesic distance from each BARRA grid point to the radar site
# geod.inv returns (forward azimuth, back azimuth, distance in metres)
_, _, dists = geod.inv(
    np.full_like(barra_lon_2d, float(RadarXR.longitude)),  # radar lon repeated
    np.full_like(barra_lat_2d, float(RadarXR.latitude)),   # radar lat repeated
    barra_lon_2d,                                           # BARRA grid lons
    barra_lat_2d,                                           # BARRA grid lats
)

# Convert distance threshold to metres and create boolean mask
# True = inside the radius, False = outside
WithinRadiusMask = dists <= (BoxRange * 1000)

print(f'Total BARRA grid points:          {barra_lon_2d.size}')
print(f'Grid points within {BoxRange} km:      {WithinRadiusMask.sum()}')
print(f'Fraction within {BoxRange} km:         {WithinRadiusMask.mean():.2%}')

# %%
# CHOOSE YOUR SOUNDING DATA
Ztime = '00'
UpperAirSiteID = '95282'
# 95282 for Townsville, 
# 94299 for Willis Island


# sounding data follow-on and loading
SoundingFolder = '/home/563/sg3241/TownsvilleSoundings/' 
SoundingFileName = RadarFileDate + Ztime + '-' + UpperAirSiteID + '.csv'
SoundingPath = SoundingFolder + SoundingFileName

SoundingData = pd.read_csv(SoundingPath)

# %%
# Build the interpolator once
sounding_interp = interp1d(SoundingData['geopotential height_m'].values,
                           SoundingData['temperature_C'].values,
                           kind='linear',
                           bounds_error=False,
                           fill_value=np.nan)

# %%
# calculate what the Sounding Data would be for every altitude (slightly different for each BARRA column)
TDayDataSounding = sounding_interp(ZDayData.zg.values)

# calculate the difference of BARRA 2 from the Sounding
TDayDataSoundingDiff = (TDayData.ta-273.15) - TDayDataSounding

# %%
# CHAD ATTEMPT

# CREATE 3 x 3 HISTOGRAMS OF TEMPERATURE DIFFERENCE BETWEEN BARRA AND REAL SOUNDING

# --- Histogram of sounding temperature differences at each pressure level ---
# within the 150 km radar radius only

fig, axes = plt.subplots(3, 3, figsize=(12, 10))  # 3x3 grid for 9 pressure levels
axes = axes.ravel()  # flatten to 1D for easy indexing

for pi in range(np.shape(TDayDataSoundingDiff)[0]):
    
    # Extract all times for this pressure level: (time, lat, lon)
    slice_3d = TDayDataSoundingDiff.isel(pressure=pi).values  # (time, lat, lon)
    
    # Apply the 2D spatial mask (lat, lon) — broadcasts across time dimension
    # WithinRadiusMask is (lat, lon), slice_3d is (time, lat, lon)
    slice_masked = slice_3d[:, WithinRadiusMask]  # (time, N_points_within_radius)
    
    # Flatten all times and spatial points into one 1D array
    slice_flat = slice_masked.ravel()
    
    # Drop NaNs before plotting
    slice_flat = slice_flat[~np.isnan(slice_flat)]
    
    # --- Plot ---
    axes[pi].hist(slice_flat, bins=np.arange(-5, 5.1, 0.1), color='steelblue', edgecolor='none')
    axes[pi].set_title(f'Pressure level {pi} — {float(TDayDataSoundingDiff.pressure[pi]):.1f} hPa')
    axes[pi].set_xlabel('Temperature Difference (BARRA - Sounding) [°C]')
    axes[pi].set_ylabel('Count')
    axes[pi].axvline(0, color='red', linewidth=1, linestyle='--')
    axes[pi].set_xlim(-5, 5)
    axes[pi].set_ylim(0, 2100)
    axes[pi].grid(True)

plt.suptitle(f'BARRA vs Sounding Temperature Difference\n{RadarSiteName} — {RadarFileDate}', 
             fontsize=13)
plt.tight_layout()

# %%
# CHAD ATTEMPT

# CREATE 2D HEAT MAP HISTOGRAM OF TEMPERATURE DIFFERENCE BETWEEN BARRA AND REAL SOUNDING

# --- 2D histogram: pressure level vs temperature difference ---

# Define bin edges
temp_bins = np.arange(-5, 5.1, 0.1)   # 0.1 °C bins from -3 to +3
temp_bin_centres = (temp_bins[:-1] + temp_bins[1:]) / 2  # centre of each bin

# Get pressure values for y axis
pressure_vals = TDayDataSoundingDiff.pressure.values  # (9,)

# --- Build 2D histogram array: (pressure, temp_bins) ---
hist_2d = np.zeros((np.shape(TDayDataSoundingDiff)[0], len(temp_bins) - 1))

for pi in range(np.shape(TDayDataSoundingDiff)[0]):
    
    # Extract and mask slice as before
    slice_3d   = TDayDataSoundingDiff.isel(pressure=pi).values   # (time, lat, lon)
    slice_masked = slice_3d[:, WithinRadiusMask]                  # (time, N_points)
    slice_flat   = slice_masked.ravel()
    slice_flat   = slice_flat[~np.isnan(slice_flat)]

    # Count occurrences in each bin
    counts, _ = np.histogram(slice_flat, bins=temp_bins)
    hist_2d[pi, :] = counts

# --- Plot ---
fig, ax = plt.subplots(figsize=(10, 6))

pcm = ax.pcolormesh(
    temp_bin_centres,
    pressure_vals,
    hist_2d,
    cmap='gist_stern',
    vmin=0,
    vmax=2500,
)

ax.set_xlabel('Temperature Difference (BARRA - Sounding) [°C]')
ax.set_ylabel('Pressure Level [hPa]')
ax.set_xlim(-5, 5)
ax.invert_yaxis()  # higher pressure (lower altitude) at bottom
ax.axvline(0, color='white', linewidth=1.5, linestyle='--')
ax.grid(True, alpha=0.4)

plt.colorbar(pcm, ax=ax, label='Absolute Occurrences')
plt.title(f'BARRA Temperature Deviation from Townsville Sounding\nFor {RadarSiteName} Radar Domain (150 km Radius) on {RadarFileDatePrint}')
plt.tight_layout()

SaveFolder = '/scratch/v46/sg3241/tmp/pngImages/'
SaveFile   = RadarIDno + '_' + RadarFileDate + '_BARRAtempDiff.png'

SavePath = SaveFolder + SaveFile

if not Path(SaveFolder).exists():
    print('Creating Folder: ' + SaveFolder)
    Path(SaveFolder).mkdir(parents=True, exist_ok=True)

plt.savefig(SavePath, bbox_inches='tight', facecolor='w', dpi = 300)
plt.close()
